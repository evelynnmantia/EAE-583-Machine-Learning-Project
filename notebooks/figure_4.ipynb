# %% [markdown]
# # Random Forest Regressor Predicted MESH vs Actual MESH
#
# ## *Must run code from the hail_random_forest notebook before running this code to create the figure*

# %%
# import necessary packages
import matplotlib.pyplot as plt

#plotting code
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red')
plt.xlabel('Actual MESH (mm)')
plt.ylabel('Predicted MESH (mm)')
plt.title('Actual vs Predicted MESH')
plt.show()
